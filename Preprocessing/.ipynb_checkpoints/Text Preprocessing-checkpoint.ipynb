# %% [markdown]
# # Text Preprocessing for Reddit Comment Classification
#
# Took some steps from these articles:
# https://www.dataquest.io/blog/natural-language-processing-with-python/
# https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
# https://mlwhiz.com/blog/2019/01/17/deeplearning_nlp_preprocess/?utm_campaign=shareaholic&utm_medium=reddit&utm_source=news

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.tag import pos_tag_sents

comment_data = pd.read_csv('../Data/reddit_train.csv')
print(comment_data)
# Out:
#           id                                           comments  \
# 0          0  Honestly, Buffalo is the correct answer. I rem...
# 1          1  Ah yes way could have been :( remember when he...
# 2          2  https://youtu.be/6xxbBR8iSZ0?t=40m49s\n\nIf yo...
# 3          3  He wouldn't have been a bad signing if we woul...
# 4          4  Easy. You use the piss and dry technique. Let ...
# ...      ...                                                ...
# 69995  69995  Thank you, you confirm Spain does have nice pe...
# 69996  69996  Imagine how many he would have killed with a r...
# 69997  69997  Yes. Only. As in the guy I was replying to was...
# 69998  69998  Looking for something light-hearted or has a v...
# 69999  69999  I love how I never cry about casters because I...
#
#             subreddits
# 0               hockey
# 1                  nba
# 2      leagueoflegends
# 3               soccer
# 4                funny
# ...                ...
# 69995           europe
# 69996  leagueoflegends
# 69997           canada
# 69998            anime
# 69999  GlobalOffensive
#
# [70000 rows x 3 columns]

# %% [markdown]
# ### Tokenization and Tagging

# %%
# tokenize comments using Twitter-specific tokenizer (couldn't find a Reddit one)
tt = TweetTokenizer()
comment_data['comments_tokens'] = comment_data['comments'].apply(tt.tokenize)

# tag comments
print(comment_data['comments'].tolist())
comment_data['comments_tagged'] = pos_tag_sents(comment_data['comments_tokens'].tolist())

# TODO count totals of each part of speech (noun, adjective, etc)

# TODO typo correction

print(comment_data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#           id                                           comments  \
# 0          0  Honestly, Buffalo is the correct answer. I rem...
# 1          1  Ah yes way could have been :( remember when he...
# 2          2  https://youtu.be/6xxbBR8iSZ0?t=40m49s\n\nIf yo...
# 3          3  He wouldn't have been a bad signing if we woul...
# 4          4  Easy. You use the piss and dry technique. Let ...
# ...      ...                                                ...
# 69995  69995  Thank you, you confirm Spain does have nice pe...
# 69996  69996  Imagine how many he would have killed with a r...
# 69997  69997  Yes. Only. As in the guy I was replying to was...
# 69998  69998  Looking for something light-hearted or has a v...
# 69999  69999  I love how I never cry about casters because I...
#
#             subreddits                                    comments_tokens  \
# 0               hockey  [Honestly, ,, Buffalo, is, the, correct, answe...
# 1                  nba  [Ah, yes, way, could, have, been, :(, remember...
# 2      leagueoflegends  [https://youtu.be/6xxbBR8iSZ0?t=40m49s, If, yo...
# 3               soccer  [He, wouldn't, have, been, a, bad, signing, if...
# 4                funny  [Easy, ., You, use, the, piss, and, dry, techn...
# ...                ...                                                ...
# 69995           europe  [Thank, you, ,, you, confirm, Spain, does, hav...
# 69996  leagueoflegends  [Imagine, how, many, he, would, have, killed, ...
# 69997           canada  [Yes, ., Only, ., As, in, the, guy, I, was, re...
# 69998            anime  [Looking, for, something, light-hearted, or, h...
# 69999  GlobalOffensive  [I, love, how, I, never, cry, about, casters, ...
#
#                                          comments_tagged
# 0      [(Honestly, RB), (,, ,), (Buffalo, NNP), (is, ...
# 1      [(Ah, NNP), (yes, PRP), (way, NN), (could, MD)...
# 2      [(https://youtu.be/6xxbBR8iSZ0?t=40m49s, NN), ...
# 3      [(He, PRP), (wouldn't, WDT), (have, VBP), (bee...
# 4      [(Easy, NNP), (., .), (You, PRP), (use, VBP), ...
# ...                                                  ...
# 69995  [(Thank, NNP), (you, PRP), (,, ,), (you, PRP),...
# 69996  [(Imagine, NNP), (how, WRB), (many, JJ), (he, ...
# 69997  [(Yes, UH), (., .), (Only, RB), (., .), (As, I...
# 69998  [(Looking, VBG), (for, IN), (something, NN), (...
# 69999  [(I, PRP), (love, VBP), (how, WRB), (I, PRP), ...
#
# [70000 rows x 5 columns]

# %% [markdown]
# ### Word Count, N-Grams, Stopword Removal

# %%
from sklearn.feature_extraction.text import CountVectorizer

# in the bag of words matrix, remove punctuation and stopwords
count_vectorizer = CountVectorizer(tokenizer=tt.tokenize, stop_words="english", ngram_range=(1,3))
counts = count_vectorizer.fit_transform(comment_data.comments)
count_vectorizer.vocabulary_
# Out:
# {'honestly': 1206519,
#  ',': 88817,
#  'buffalo': 612966,
#  'correct': 751050,
#  'answer': 477920,
#  '.': 198352,
#  'remember': 1899247,
#  'people': 1710572,
#  '(': 40846,
#  'somewhat': 2070287,
#  ')': 61095,
#  'joking': 1336483,
#  "buffalo's": 613061,
#  'mantra': 1524434,
#  'starting': 2104889,
#  'goalies': 1089794,
#  '"': 4983,
#  'win': 2406401,
#  'game': 1056729,
#  'traded': 2269186,
#  'think': 2219798,
#  "edmonton's": 910412,
#  'office': 1657019,
#  'travesty': 2274803,
#  'better': 562153,
#  '10': 319453,
#  'years': 2451133,
#  'systematic': 2161829,
#  'destruction': 823849,
#  'term': 2191808,
#  "'": 35016,
#  'competitive': 722087,
#  'responsible': 1913422,
#  'change': 663297,
#  'draft': 884753,
#  'lottery': 1490053,
#  'honestly ,': 1206528,
#  ', buffalo': 103706,
#  'buffalo correct': 613008,
#  'correct answer': 751200,
#  'answer .': 477987,
#  '. remember': 270526,
#  'remember people': 1900339,
#  'people (': 1710664,
#  '( somewhat': 58942,
#  'somewhat )': 2070293,
#  ') joking': 68844,
#  "joking buffalo's": 1336522,
#  "buffalo's mantra": 613062,
#  'mantra starting': 1524446,
#  'starting goalies': 2105132,
#  'goalies "': 1089795,
#  '" win': 27523,
#  'win game': 2407046,
#  'game ,': 1056838,
#  ', traded': 179692,
#  'traded "': 2269187,
#  '" .': 6572,
#  '. think': 284285,
#  "think edmonton's": 2222515,
#  "edmonton's office": 910419,
#  'office travesty': 1657332,
#  'travesty better': 2274811,
#  'better 10': 562651,
#  '10 years': 320731,
#  'years ,': 2451221,
#  ", buffalo's": 103713,
#  "buffalo's systematic": 613064,
#  'systematic destruction': 2161836,
#  'destruction term': 823928,
#  "term '": 2191831,
#  "' competitive": 36655,
#  "competitive '": 722088,
#  "' responsible": 39228,
#  'responsible change': 1913476,
#  'change draft': 663797,
#  'draft lottery': 884929,
#  'lottery .': 1490063,
#  'honestly , buffalo': 1206545,
#  ', buffalo correct': 103709,
#  'buffalo correct answer': 613009,
#  'correct answer .': 751202,
#  'answer . remember': 478022,
#  '. remember people': 270627,
#  'remember people (': 1900340,
#  'people ( somewhat': 1710705,
#  '( somewhat )': 58943,
#  'somewhat ) joking': 2070296,
#  ") joking buffalo's": 68845,
#  "joking buffalo's mantra": 1336523,
#  "buffalo's mantra starting": 613063,
#  'mantra starting goalies': 1524447,
#  'starting goalies "': 2105133,
#  'goalies " win': 1089796,
#  '" win game': 27528,
#  'win game ,': 2407049,
#  'game , traded': 1057091,
#  ', traded "': 179693,
#  'traded " .': 2269188,
#  '" . think': 7086,
#  ". think edmonton's": 284514,
#  "think edmonton's office": 2222516,
#  "edmonton's office travesty": 910420,
#  'office travesty better': 1657333,
#  'travesty better 10': 2274812,
#  'better 10 years': 562653,
#  '10 years ,': 320733,
#  "years , buffalo's": 2451254,
#  ", buffalo's systematic": 103714,
#  "buffalo's systematic destruction": 613065,
#  'systematic destruction term': 2161837,
#  "destruction term '": 823929,
#  "term ' competitive": 2191833,
#  "' competitive '": 36656,
#  "competitive ' responsible": 722089,
#  "' responsible change": 39229,
#  'responsible change draft': 1913477,
#  'change draft lottery': 663798,
#  'draft lottery .': 884930,
#  'ah': 454434,
#  'yes': 2454770,
#  'way': 2378334,
#  ':(': 380451,
#  'drafted': 885084,
#  'thought': 2232151,
#  'gonna': 1100221,
#  'great': 1120862,
#  'nope': 1639133,
#  'kawhi': 1362488,
#  'thompson': 2231729,
#  'jimmy': 1331467,
#  'butler': 620571,
#  'ah yes': 454647,
#  'yes way': 2456182,
#  'way :(': 2379114,
#  ':( remember': 380577,
#  'remember drafted': 1899772,
#  'drafted thought': 885239,
#  'thought gonna': 2233175,
#  'gonna great': 1100683,
#  'great nope': 1122672,
#  'nope kawhi': 1639289,
#  'kawhi thompson': 1362546,
#  'thompson jimmy': 2231762,
#  'jimmy butler': 1331481,
#  'ah yes way': 454655,
#  'yes way :(': 2456184,
#  'way :( remember': 2379115,
#  ':( remember drafted': 380578,
#  'remember drafted thought': 1899773,
#  'drafted thought gonna': 885240,
#  'thought gonna great': 2233180,
#  'gonna great nope': 1100689,
#  'great nope kawhi': 1122673,
#  'nope kawhi thompson': 1639290,
#  'kawhi thompson jimmy': 1362547,
#  'thompson jimmy butler': 2231763,
#  'https://youtu.be/6xxbbr8isz0?t=40m49s': 1231256,
#  "didn't": 833720,
#  'ordinary': 1676646,
#  'just': 1342728,
#  'eye': 967703,
#  'constant': 737761,
#  'contact': 739210,
#  "https://youtu.be/6xxbbr8isz0?t=40m49s didn't": 1231257,
#  "didn't .": 833798,
#  '. ordinary': 261522,
#  'ordinary ,': 1676647,
#  ', just': 137505,
#  'just eye': 1347481,
#  'eye constant': 967812,
#  'constant eye': 737823,
#  'eye contact': 967814,
#  'contact .': 739229,
#  "https://youtu.be/6xxbbr8isz0?t=40m49s didn't .": 1231258,
#  "didn't . ordinary": 833845,
#  '. ordinary ,': 261523,
#  'ordinary , just': 1676648,
#  ', just eye': 137819,
#  'just eye constant': 1347482,
#  'eye constant eye': 967813,
#  'constant eye contact': 737824,
#  'eye contact .': 967817,
#  "wouldn't": 2433223,
#  'bad': 525944,
#  'signing': 2039002,
#  'paid': 1690545,
#  '18m': 329196,
#  'euros': 946284,
#  'right': 1924190,
#  'price': 1802675,
#  'acceptable': 425430,
#  "wouldn't bad": 2433431,
#  'bad signing': 528350,
#  "signing wouldn't": 2039245,
#  "wouldn't paid": 2434315,
#  'paid 18m': 1690654,
#  '18m euros': 329203,
#  'euros .': 946297,
#  '. right': 271600,
#  'right price': 1926938,
#  'price acceptable': 1802799,
#  'acceptable .': 425448,
#  "wouldn't bad signing": 2433441,
#  "bad signing wouldn't": 528352,
#  "signing wouldn't paid": 2039247,
#  "wouldn't paid 18m": 2434316,
#  'paid 18m euros': 1690655,
#  '18m euros .': 329204,
#  'euros . right': 946304,
#  '. right price': 271663,
#  'right price acceptable': 1926942,
#  'price acceptable .': 1802800,
#  'easy': 905285,
#  'use': 2320918,
#  'piss': 1740338,
#  'dry': 893468,
#  'technique': 2186313,
#  'let': 1420833,
#  'drops': 891706,
#  'rinse': 1929385,
#  'repeat': 1904147,
#  'lucky': 1498051,
#  'end': 921891,
#  'using': 2328005,
#  'hot': 1213499,
#  'sunny': 2144070,
#  'day': 792701,
#  'process': 1813499,
#  'lot': 1485580,
#  'faster': 987700,
#  'easy .': 905338,
#  '. use': 289208,
#  'use piss': 2323058,
#  'piss dry': 1740394,
#  'dry technique': 893575,
#  'technique .': 2186324,
#  '. let': 250424,
#  'let drops': 1421305,
#  'drops ,': 891713,
#  ', let': 141568,
#  'let dry': 1421311,
#  'dry ,': 893473,
#  ', rinse': 164535,
#  'rinse repeat': 1929398,
#  'repeat .': 1904162,
#  '. lucky': 253946,
#  'lucky end': 1498195,
#  'end using': 923812,
#  'using piss': 2329075,
#  'technique hot': 2186347,
#  'hot sunny': 1213898,
#  'sunny day': 2144075,
#  'day ,': 792763,
#  ', process': 159133,
#  'process lot': 1813734,
#  'lot faster': 1486859,
#  'faster .': 987730,
#  'easy . use': 905371,
#  '. use piss': 289307,
#  'use piss dry': 2323059,
#  'piss dry technique': 1740395,
#  'dry technique .': 893576,
#  'technique . let': 2186327,
#  '. let drops': 250450,
#  'let drops ,': 1421306,
#  'drops , let': 891716,
#  ', let dry': 141611,
#  'let dry ,': 1421312,
#  'dry , rinse': 893478,
#  ', rinse repeat': 164537,
#  'rinse repeat .': 1929400,
#  'repeat . lucky': 1904174,
#  '. lucky end': 253953,
#  'lucky end using': 1498196,
#  'end using piss': 923813,
#  'using piss dry': 2329076,
#  'dry technique hot': 893577,
#  'technique hot sunny': 2186348,
#  'hot sunny day': 1213899,
#  'sunny day ,': 2144076,
#  'day , process': 792882,
#  ', process lot': 159138,
#  'process lot faster': 1813736,
#  'lot faster .': 1486860,
#  'joke': 1335600,
#  '!': 0,
#  "i've": 1249153,
#  'seen': 1996810,
#  'twice': 2295667,
#  '...': 297440,
#  ':/': 380940,
#  'joke !': 1335601,
#  "! i've": 2619,
#  "i've seen": 1251139,
#  'seen twice': 1998543,
#  'twice ...': 2295732,
#  '... :/': 298016,
#  "joke ! i've": 1335602,
#  "! i've seen": 2633,
#  "i've seen twice": 1251395,
#  'seen twice ...': 1998544,
#  'twice ... :/': 2295733,
#  'role': 1936264,
#  'mi3': 1562177,
#  'best': 557749,
#  'villians': 2345025,
#  'movie': 1594508,
#  'genuinely': 1072543,
#  'felt': 998074,
#  'like': 1431854,
#  'shit': 2022258,
#  'loved': 1493508,
#  'inflict': 1279108,
#  'pain': 1691196,
#  'wanted': 2364313,
#  'nailed': 1607031,
#  'lack': 1393927,
#  'remorse': 1901853,
#  'love': 1490608,
#  'helps': 1185263,
#  'story': 2120418,
#  'centered': 656173,
#  'personal': 1727339,
#  'hunt': 1235625,
#  'women': 2414642,
#  'life': 1428608,
#  'role mi3': 1936593,
#  'mi3 best': 1562178,
#  'best villians': 561085,
#  "villians i've": 2345032,
#  'seen movie': 1997943,
#  'movie genuinely': 1595326,
#  'genuinely felt': 1072622,
#  'felt like': 998340,
#  'like just': 1440696,
#  "just didn't": 1346356,
#  "didn't shit": 836521,
#  'shit people': 2024305,
#  'people loved': 1716508,
#  'loved inflict': 1493801,
#  'inflict pain': 1279115,
#  'pain wanted': 1691468,
#  'wanted .': 2364368,
#  '. nailed': 258515,
#  'nailed lack': 1607056,
#  'lack remorse': 1394334,
#  'remorse just': 1901863,
#  'just love': 1351457,
#  'love movie': 1492409,
#  'movie .': 1594686,
#  '. helps': 238376,
#  'helps story': 1185502,
#  'story centered': 2120827,
#  'centered personal': 656195,
#  'personal hunt': 1727601,
#  'hunt women': 1235686,
#  'women loved': 2415067,
#  'loved life': 1493830,
#  'life .': 1428754,
#  'role mi3 best': 1936594,
#  'mi3 best villians': 1562179,
#  "best villians i've": 561086,
#  "villians i've seen": 2345033,
#  "i've seen movie": 1251301,
#  'seen movie genuinely': 1997948,
#  'movie genuinely felt': 1595327,
#  'genuinely felt like': 1072624,
#  'felt like just': 998407,
#  "like just didn't": 1440711,
#  "just didn't shit": 1346388,
#  "didn't shit people": 836528,
#  'shit people loved': 2024313,
#  'people loved inflict': 1716512,
#  'loved inflict pain': 1493802,
#  'inflict pain wanted': 1279116,
#  'pain wanted .': 1691469,
#  'wanted . nailed': 2364404,
#  '. nailed lack': 258518,
#  'nailed lack remorse': 1607057,
#  'lack remorse just': 1394335,
#  'remorse just love': 1901864,
#  'just love movie': 1351476,
#  'love movie .': 1492412,
#  'movie . helps': 1594749,
#  '. helps story': 238395,
#  'helps story centered': 1185503,
#  'story centered personal': 2120828,
#  'centered personal hunt': 656196,
#  'personal hunt women': 1727602,
#  'hunt women loved': 1235687,
#  'women loved life': 2415068,
#  'loved life .': 1493831,
#  'akagi': 457898,
#  'alpha': 465605,
#  'fuck': 1043451,
#  'sugawara': 2140949,
#  'suffering': 2140527,
#  'definitely': 810018,
#  'favorite': 989799,
#  'couples': 760138,
#  'far': 983965,
#  'akagi alpha': 457899,
#  'alpha fuck': 465641,
#  'fuck sugawara': 1045153,
#  'sugawara suffering': 2140950,
#  'suffering .': 2140538,
#  '. definitely': 222026,
#  'definitely favorite': 810547,
#  'favorite couples': 990045,
#  'couples far': 760154,
#  'far .': 984087,
#  'akagi alpha fuck': 457900,
#  'alpha fuck sugawara': 465642,
#  'fuck sugawara suffering': 1045154,
#  'sugawara suffering .': 2140951,
#  'suffering . definitely': 2140540,
#  '. definitely favorite': 222062,
#  'definitely favorite couples': 810549,
#  'favorite couples far': 990046,
#  'couples far .': 760155,
#  "other's": 1679976,
#  'detonator': 824993,
#  'proven': 1824306,
#  'joker': 1336199,
#  'blew': 580323,
#  'boat': 585704,
#  '-': 189091,
#  'boatload': 585869,
#  'survivors': 2156116,
#  'attest': 511938,
#  "wasn't": 2370289,
#  'pulled': 1829443,
#  'trigger': 2278685,
#  "think other's": 2226187,
#  "other's detonator": 1679987,
#  'detonator .': 824994,
#  ". wouldn't": 294117,
#  "wouldn't proven": 2434415,
#  'proven joker': 1824393,
#  'joker right': 1336222,
#  'right blew': 1925549,
#  'blew boat': 580345,
#  'boat -': 585728,
#  "- wouldn't": 197926,
#  "wouldn't boatload": 2433489,
#  'boatload survivors': 585874,
#  'survivors attest': 2156127,
#  'attest joker': 511948,
#  "joker wasn't": 1336227,
#  "wasn't pulled": 2371739,
#  'pulled trigger': 1829674,
#  'trigger .': 2278702,
#  "think other's detonator": 2226188,
#  "other's detonator .": 1679988,
#  "detonator . wouldn't": 824995,
#  ". wouldn't proven": 294203,
#  "wouldn't proven joker": 2434416,
#  'proven joker right': 1824394,
#  'joker right blew': 1336223,
#  'right blew boat': 1925550,
#  'blew boat -': 580346,
#  "boat - wouldn't": 585729,
#  "- wouldn't boatload": 197927,
#  "wouldn't boatload survivors": 2433490,
#  'boatload survivors attest': 585875,
#  'survivors attest joker': 2156128,
#  "attest joker wasn't": 511949,
#  "joker wasn't pulled": 1336228,
#  "wasn't pulled trigger": 2371740,
#  'pulled trigger .': 1829675,
#  'disruptor': 853236,
#  'tank': 2172247,
#  'pull': 1828991,
#  'dps': 883901,
#  'frey': 1039166,
#  'pick': 1734496,
#  'point': 1766003,
#  "can't": 631006,
#  'reliably': 1896853,
#  'hero': 1186621,
#  'expect': 958452,
#  "it's": 1308910,
#  'heartbreaking': 1179173,
#  '..': 296024,
#  'right !': 1924191,
#  '! disruptor': 1658,
#  'disruptor tank': 853241,
#  'tank !': 2172248,
#  '! pull': 3705,
#  'pull dps': 1829139,
#  'dps frey': 884148,
#  'frey pick': 1039193,
#  'pick ,': 1734528,
#  ', point': 157003,
#  'point .': 1766282,
#  ". can't": 215009,
#  "can't reliably": 633455,
#  'reliably hero': 1896865,
#  'hero expect': 1186880,
#  'expect win': 959215,
#  'win ...': 2406586,
#  "... it's": 300641,
#  "it's heartbreaking": 1314406,
#  'heartbreaking ..': 1179180,
#  'right ! disruptor': 1924199,
#  '! disruptor tank': 1659,
#  'disruptor tank !': 853242,
#  'tank ! pull': 2172250,
#  '! pull dps': 3707,
#  'pull dps frey': 1829140,
#  'dps frey pick': 884149,
#  'frey pick ,': 1039194,
#  'pick , point': 1734556,
#  ', point .': 157007,
#  "point . can't": 1766318,
#  ". can't reliably": 215213,
#  "can't reliably hero": 633456,
#  'reliably hero expect': 1896866,
#  'hero expect win': 1186881,
#  'expect win ...': 959216,
#  "win ... it's": 2406589,
#  "... it's heartbreaking": 300686,
#  "it's heartbreaking ..": 1314408,
#  'flying': 1019717,
#  'eagles': 900734,
#  'mordor': 1589729,
#  'thing': 2213813,
#  'incredibly': 1274668,
#  'divisive': 855747,
#  'heard': 1177359,
#  'fight': 1001840,
#  'forth': 1031277,
#  'plot': 1763494,
#  'hole': 1202926,
#  "i'm": 1242090,
#  'looking': 1478624,
#  'insight': 1284994,
#  'flying eagles': 1019806,
#  'eagles mordor': 900827,
#  'mordor thing': 1589732,
#  'thing incredibly': 2215607,
#  'incredibly divisive': 1274766,
#  'divisive .': 855750,
#  ". i've": 241783,
#  "i've heard": 1250091,
#  'heard people': 1178078,
#  'people fight': 1714409,
#  'fight forth': 1002274,
#  "forth it's": 1031335,
#  "it's plot": 1318014,
#  'plot hole': 1763666,
#  'hole .': 1202945,
#  ". i'm": 241212,
#  "i'm looking": 1245804,
#  'looking insight': 1479340,
#  'insight .': 1285000,
#  'flying eagles mordor': 1019807,
#  'eagles mordor thing': 900828,
#  'mordor thing incredibly': 1589733,
#  'thing incredibly divisive': 2215608,
#  'incredibly divisive .': 1274767,
#  "divisive . i've": 855751,
#  ". i've heard": 241904,
#  "i've heard people": 1250158,
#  'heard people fight': 1178080,
#  'people fight forth': 1714414,
#  "fight forth it's": 1002275,
#  "forth it's plot": 1031336,
#  "it's plot hole": 1318015,
#  'plot hole .': 1763668,
#  "hole . i'm": 1202957,
#  ". i'm looking": 241527,
#  "i'm looking insight": 1245827,
#  'looking insight .': 1479341,
#  'oh': 1658685,
#  'man': 1519392,
#  'wait': 2354792,
#  'vote': 2350368,
#  '*': 74128,
#  'opens': 1670567,
#  'link': 1454245,
#  'starts': 2105577,
#  'sweating': 2157942,
#  '" oh': 20110,
#  'oh man': 1659402,
#  "man can't": 1520119,
#  "can't wait": 634316,
#  'wait vote': 2355749,
#  'vote .': 2350428,
#  '. "': 198482,
#  '" *': 5861,
#  '* opens': 83579,
#  'opens link': 1670600,
#  'link *': 1454265,
#  '* *': 74360,
#  '* starts': 85608,
#  'starts sweating': 2105946,
#  'sweating *': 2157943,
#  '" oh man': 20146,
#  "oh man can't": 1659409,
#  "man can't wait": 1520122,
#  "can't wait vote": 634386,
#  'wait vote .': 2355750,
#  'vote . "': 2350429,
#  '. " *': 198490,
#  '" * opens': 5923,
#  '* opens link': 83580,
#  'opens link *': 1670601,
#  'link * *': 1454266,
#  '* * starts': 76090,
#  '* starts sweating': 85610,
#  'starts sweating *': 2105947,
#  'omg': 1665489,
#  'thinking': 2229722,
#  'azumi': 523103,
#  'u': 2299406,
#  'af': 446538,
#  'boi': 587094,
#  'omg thinking': 1665595,
#  'thinking ...': 2229848,
#  '... azumi': 298399,
#  'azumi u': 523106,
#  'u alpha': 2299782,
#  'alpha af': 465624,
#  'af boi': 446573,
#  'omg thinking ...': 1665596,
#  'thinking ... azumi': 2229850,
#  '... azumi u': 298400,
#  'azumi u alpha': 523107,
#  'u alpha af': 2299783,
#  'alpha af boi': 465625,
#  'shot': 2029583,
#  'kill': 1369566,
#  "that's": 2198391,
#  'character': 666981,
#  'shot ,': 2029607,
#  ', kill': 139195,
#  'kill !': 1369567,
#  '! wait': 4638,
#  'wait ...': 2354946,
#  "... that's": 303028,
#  "that's right": 2202380,
#  'right character': 1925663,
#  'character ...': 667173,
#  'shot , kill': 2029631,
#  ', kill !': 139196,
#  'kill ! wait': 1369571,
#  '! wait ...': 4640,
#  "wait ... that's": 2354966,
#  "... that's right": 303078,
#  "that's right character": 2202388,
#  'right character ...': 1925664,
#  'new': 1625288,
#  'sub': 2134143,
#  'curious': 777497,
#  '1-10': 318399,
#  'things': 2217150,
#  'describing': 820207,
#  'high': 1190128,
#  '?': 393560,
#  "i'm new": 1246147,
#  'new sub': 1628011,
#  'sub curious': 2134389,
#  'curious .': 777526,
#  '. 1-10': 202488,
#  '1-10 things': 318407,
#  'things describing': 2217999,
#  'describing high': 820227,
#  'high ?': 1190320,
#  "i'm new sub": 1246150,
#  'new sub curious': 1628013,
#  'sub curious .': 2134390,
#  'curious . 1-10': 777529,
#  '. 1-10 things': 202489,
#  '1-10 things describing': 318408,
#  'things describing high': 2218000,
#  'describing high ?': 820228,
#  'pay': 1705159,
#  '$': 29655,
#  '220': 342353,
#  '/': 303936,
#  'oz': 1688068,
#  'brooklyn': 608305,
#  'mid': 1563139,
#  'range': 1851877,
#  'trees': 2276057,
#  'grade': 1118023,
#  'run': 1946470,
#  '300': 349630,
#  '450': 356237,
#  'pay $': 1705166,
#  '$ 220': 30224,
#  '220 /': 342354,
#  '/ oz': 310339,
#  'oz brooklyn': 1688086,
#  'brooklyn mid': 608329,
#  'mid range': 1563471,
#  'range trees': 1852258,
#  'trees .': 2276096,
#  '. high': 238631,
#  'high grade': 1190799,
#  'grade run': 1118146,
#  'run $': 1946479,
#  '$ 300': 30343,
#  '300 -': 349655,
#  '- $': 189194,
#  '$ 450': 30488,
#  '450 .': 356238,
#  'pay $ 220': 1705176,
#  '$ 220 /': 30225,
#  '220 / oz': 342355,
#  '/ oz brooklyn': 310340,
#  'oz brooklyn mid': 1688087,
#  'brooklyn mid range': 608330,
#  'mid range trees': 1563474,
#  'range trees .': 1852259,
#  'trees . high': 2276109,
#  '. high grade': 238650,
#  'high grade run': 1190801,
#  'grade run $': 1118147,
#  'run $ 300': 1946482,
#  '$ 300 -': 30344,
#  '300 - $': 349656,
#  '- $ 450': 189211,
#  '$ 450 .': 30489,
#  'glad': 1086133,
#  "you're": 2458945,
#  'considering': 735705,
#  'rewatch': 1920382,
#  'series': 2006808,
#  'perfect': 1722328,
#  'certainly': 658549,
#  'enjoyable': 929579,
#  'personally': 1728106,
#  'did': 829172,
#  'subaru': 2134954,
#  'interesting': 1291768,
#  'characters': 668312,
#  'added': 440467,
#  'cast': 648119,
#  'later': 1401448,
#  "i'm glad": 1244425,
#  "glad you're": 1086618,
#  "you're considering": 2459762,
#  'considering rewatch': 736217,
#  'rewatch .': 1920391,
#  '. series': 274916,
#  'series far': 2007215,
#  'far perfect': 985348,
#  "perfect it's": 1722623,
#  "it's certainly": 1310974,
#  'certainly enjoyable': 658775,
#  'enjoyable .': 929593,
#  '. personally': 263620,
#  'personally did': 1728276,
#  'did like': 831656,
#  'like subaru': 1446210,
#  'subaru interesting': 2134965,
#  'interesting characters': 1292007,
#  'characters added': 668511,
#  'added cast': 440567,
#  'cast later': 648350,
#  "i'm glad you're": 1244518,
#  "glad you're considering": 1086622,
#  "you're considering rewatch": 2459764,
#  'considering rewatch .': 736218,
#  'rewatch . series': 1920398,
#  '. series far': 274923,
#  'series far perfect': 2007218,
#  "far perfect it's": 985350,
#  "perfect it's certainly": 1722624,
#  "it's certainly enjoyable": 1310982,
#  'certainly enjoyable .': 658776,
#  'enjoyable . personally': 929599,
#  '. personally did': 263631,
#  'personally did like': 1728277,
#  'did like subaru': 831676,
#  'like subaru interesting': 1446212,
#  'subaru interesting characters': 2134966,
#  'interesting characters added': 1292008,
#  'characters added cast': 668512,
#  'added cast later': 440568,
#  'stories': 2119833,
#  'window': 2408055,
#  'players': 1755946,
#  'clubs': 699069,
#  'prices': 1803253,
#  'free': 1036121,
#  'page': 1689932,
#  'fodder': 1021276,
#  'tabloids': 2163642,
#  'big': 567896,
#  'shrug': 2035074,
#  "it's stories": 1320266,
#  'stories window': 2120153,
#  'window ,': 2408065,
#  ', players': 156607,
#  'players ,': 1756023,
#  ', clubs': 107422,
#  'clubs ,': 699077,
#  ', prices': 158560,
#  'prices .': 1803273,
#  '. free': 231710,
#  'free page': 1036888,
#  'page fodder': 1690144,
#  'fodder tabloids': 1021290,
#  'tabloids .': 2163647,
#  '. big': 212472,
#  'big shrug': 569879,
#  'shrug .': 2035079,
#  "it's stories window": 1320269,
#  'stories window ,': 2120154,
#  'window , players': 2408074,
#  ', players ,': 156610,
#  'players , clubs': 1756035,
#  ', clubs ,': 107423,
#  'clubs , prices': 699087,
#  ', prices .': 158561,
#  'prices . free': 1803280,
#  '. free page': 231732,
#  'free page fodder': 1036889,
#  'page fodder tabloids': 1690145,
#  'fodder tabloids .': 1021291,
#  'tabloids . big': 2163648,
#  '. big shrug': 212552,
#  'big shrug .': 569880,
#  'willing': 2405621,
#  'negotiate': 1622223,
#  'contract': 742484,
#  'transfer': 2272008,
#  'ban': 532659,
#  'valid': 2333225,
#  'reason': 1873612,
#  'lol': 1470444,
#  'mate': 1533259,
#  'trying': 2287959,
#  'defend': 807247,
#  'incompetent': 1273058,
#  'barca': 536805,
#  'board': 585318,
#  'bunch': 616810,
#  'corrupt': 751994,
#  'exactly': 951242,
#  'good': 1101582,
#  'businessmen': 620118,
#  'past': 1701790,
#  'transfers': 2272360,
#  'knows': 1388050,
#  'incompetence': 1273019,
#  'showed': 2032501,
#  'said': 1957637,
#  'willing negotiate': 2405848,
#  'negotiate contract': 1622235,
#  'contract transfer': 743064,
#  'transfer ban': 2272040,
#  'ban valid': 533000,
#  'valid reason': 2333354,
#  'reason .': 1873737,
#  '. lol': 252478,
#  'lol mate': 1471259,
#  'mate trying': 1533384,
#  'trying defend': 2288457,
#  'defend incompetent': 807432,
#  'incompetent barca': 1273077,
#  'barca board': 536864,
#  'board ,': 585331,
#  ', bunch': 103851,
#  'bunch corrupt': 616936,
#  'corrupt people': 752086,
#  'people ,': 1710748,
#  ', exactly': 119376,
#  'exactly good': 951773,
#  'good businessmen': 1102905,
#  'businessmen seen': 620123,
#  'seen past': 1998032,
#  'past transfers': 1702584,
#  'transfers .': 2272369,
#  '. knows': 249126,
#  'knows incompetence': 1388462,
#  'incompetence showed': 1273049,
#  'showed said': 2032783,
#  'said .': 1958159,
#  'willing negotiate contract': 2405851,
#  'negotiate contract transfer': 1622236,
#  'contract transfer ban': 743065,
#  'transfer ban valid': 2272041,
#  'ban valid reason': 533001,
#  'valid reason .': 2333355,
#  'reason . lol': 1873806,
#  '. lol mate': 252500,
#  'lol mate trying': 1471260,
#  'mate trying defend': 1533385,
#  'trying defend incompetent': 2288463,
#  'defend incompetent barca': 807433,
#  'incompetent barca board': 1273078,
#  'barca board ,': 536865,
#  'board , bunch': 585333,
#  ', bunch corrupt': 103859,
#  'bunch corrupt people': 616937,
#  'corrupt people ,': 752087,
#  'people , exactly': 1710826,
#  ', exactly good': 119390,
#  'exactly good businessmen': 951774,
#  'good businessmen seen': 1102906,
#  'businessmen seen past': 620124,
#  'seen past transfers': 1998035,
#  'past transfers .': 1702585,
#  'transfers . knows': 2272371,
#  '. knows incompetence': 249156,
#  'knows incompetence showed': 1388463,
#  'incompetence showed said': 1273050,
#  'showed said .': 2032784,
#  'afraid': 448125,
#  "i'll": 1240642,
#  'addicted': 440909,
#  'fail': 974000,
#  'school': 1981188,
#  'smthing': 2062083,
#  "afraid i'll": 448233,
#  "i'll addicted": 1240723,
#  'addicted fail': 440934,
#  'fail school': 974178,
#  'school smthing': 1981983,
#  'smthing lol': 2062084,
#  "afraid i'll addicted": 448234,
#  "i'll addicted fail": 1240724,
#  'addicted fail school': 440935,
#  'fail school smthing': 974180,
#  'school smthing lol': 1981984,
#  'shh': 2020115,
#  'baby': 523918,
#  'okay': 1661227,
#  'got': 1109491,
#  'ring': 1928927,
#  "don't": 869194,
#  'half': 1144647,
#  'sam': 1962671,
#  'adams': 439077,
#  'calm': 628076,
#  'shh baby': 2020118,
#  'baby okay': 524158,
#  'okay got': 1661530,
#  'got ring': 1113309,
#  'ring ,': 1928941,
#  ", don't": 115148,
#  "don't think": 875633,
#  'think half': 2223421,
#  'half .': 1144692,
#  '. sam': 273142,
#  'sam adams': 1962699,
#  'adams calm': 439099,
#  'calm shh': 628178,
#  'shh baby okay': 2020119,
#  'baby okay got': 524159,
#  'okay got ring': 1661531,
#  'got ring ,': 1113311,
#  "ring , don't": 1928945,
#  ", don't think": 115524,
#  "don't think half": 875870,
#  'think half .': 2223422,
#  'half . sam': 1144716,
#  '. sam adams': 273144,
#  'sam adams calm': 1962700,
#  'adams calm shh': 439100,
#  'trampoline': 2271732,
#  'centre': 656538,
#  'sisters': 2046679,
#  'birthday': 573418,
#  'sat': 1965596,
#  'coffee': 702215,
#  'session': 2010132,
#  'comment': 712907,
#  'really': 1866369,
#  'burn': 618099,
#  'table': 2163341,
#  'slightly': 2055284,
#  'sloped': 2056050,
#  'woman': 2414143,
#  'puts': 1834187,
#  'chair': 660064,
#  'waiter': 2355897,
#  'saw': 1967848,
#  'tip': 2251465,
#  'leaps': 1410591,
#  'clean': 690855,
#  'super': 2144300,
#  'runs': 1948959,
#  'lap': 1398698,
#  'screaming': 1985549,
#  'scalding': 1977299,
#  'mum': 1599832,
#  'freaks': 1035976,
#  'knowing': 1386405,
#  'happened': 1151556,
#  'stand': 2098352,
#  'grab': 1117638,
#  'shout': 2032110,
#  'rip': 1929821,
#  'soaked': 2064042,
#  ...}

# %%
print(counts.shape)
# Out:
# (70000, 2479317)

# %% [markdown]
# ### Reducing Dimensionality
# Pick the important information out of the large matrix generated above.
#
# TODO: instead of using chi2 (which requires the subreddit list to be converted to binary values), use a score function that works for multi-class classification

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# iterate through the 20 possible classes
for subreddit in comment_data.subreddits.unique():
    print(subreddit)
    # use a binary value to represent whether this comment belongs to this subreddit
    subreddits = np.array(comment_data["subreddits"].copy(deep=True))
    subreddit_match = subreddits == subreddit
    subreddit_nomatch = subreddits != subreddit
    subreddits[subreddit_match] = 1
    subreddits[subreddit_nomatch] = 0
    
#     # select the k=1000 most useful words/n-grams (k can be varied)
#     selector = SelectKBest(chi2, k=1000)
#     selector.fit(counts, subreddits)
#     top_words = selector.get_support().nonzero()

    # Pick only the most informative columns in the data.
#     chi_matrix = full_matrix[:,top_words[0]]
# Out:
# hockey
# (70000,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-d3c218709f95> in <module>
#      16     # select the k=1000 most useful words/n-grams (k can be varied)
#      17     selector = SelectKBest(chi2, k=1000)
# ---> 18     selector.fit(counts, subreddits)
#      19     top_words = selector.get_support().nonzero()
#      20
#
# ~/venv/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# ~/venv/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in chi2(X, y)
#     216         raise ValueError("Input X must be non-negative.")
#     217
# --> 218     Y = LabelBinarizer().fit_transform(y)
#     219     if Y.shape[1] == 1:
#     220         Y = np.append(1 - Y, Y, axis=1)
#
# ~/venv/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     437             Shape will be [n_samples, 1] for binary problems.
#     438         """
# --> 439         return self.fit(y).transform(y)
#     440
#     441     def transform(self, y):
#
# ~/venv/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit(self, y)
#     414
#     415         self.sparse_input_ = sp.issparse(y)
# --> 416         self.classes_ = unique_labels(y)
#     417         return self
#     418
#
# ~/venv/lib/python3.6/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      92     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#      93     if not _unique_labels:
# ---> 94         raise ValueError("Unknown label type: %s" % repr(ys))
#      95
#      96     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([1, 0, 0, ..., 0, 0, 0], dtype=object),)

# %% [markdown]
# ### Meta-Features
# Find attributes like comment length, amount of punctuation, average word length, etc.

# %%
from pymfe.mfe import MFE

# Extract all measures
mfe = MFE()
mfe.fit(comment_data['comments'].tolist(), comment_data['subreddits'].tolist())
ft = mfe.extract()
print(ft)

# Extract general, statistical and information-theoretic measures
mfe = MFE(groups=["general", "statistical", "info-theory"])
mfe.fit(X, y)
ft = mfe.extract()
print(ft)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-37-31d79692bfd8> in <module>
#       3 # Extract all measures
#       4 mfe = MFE()
# ----> 5 mfe.fit(comment_data['comments'].tolist(), comment_data['subreddits'].tolist())
#       6 ft = mfe.extract()
#       7 print(ft)
#
# ~/venv/lib/python3.6/site-packages/pymfe/mfe.py in fit(self, X, y, transform_num, transform_cat, rescale, rescale_args, cat_cols, check_bool, precomp_groups, wildcard, suppress_warnings)
#     830             transform_cat=transform_cat,
#     831             rescale=rescale,
# --> 832             rescale_args=rescale_args)
#     833
#     834         # Custom arguments for metafeature extraction methods
#
# ~/venv/lib/python3.6/site-packages/pymfe/mfe.py in _set_data_numeric(self, transform_cat, rescale, rescale_args)
#     694         if transform_cat:
#     695             categorical_dummies = _internal.transform_cat(
# --> 696                 self.X[:, self._attr_indexes_cat])
#     697
#     698             if categorical_dummies is not None:
#
# ~/venv/lib/python3.6/site-packages/pymfe/_internal.py in transform_cat(data_categoric)
#    1285     formula = "~ 0 + {}".format(" + ".join(dummy_attr_names))
#    1286
# -> 1287     return np.asarray(patsy.dmatrix(formula, named_data))
#    1288
#    1289
#
# ~/venv/lib/python3.6/site-packages/patsy/highlevel.py in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     289     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     290     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 291                                       NA_action, return_type)
#     292     if lhs.shape[1] != 0:
#     293         raise PatsyError("encountered outcome variables for a model "
#
# ~/venv/lib/python3.6/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# ~/venv/lib/python3.6/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# ~/venv/lib/python3.6/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     719         term_to_subterm_infos = _make_subterm_infos(termlist,
#     720                                                     num_column_counts,
# --> 721                                                     cat_levels_contrasts)
#     722         assert isinstance(term_to_subterm_infos, OrderedDict)
#     723         assert frozenset(term_to_subterm_infos) == frozenset(termlist)
#
# ~/venv/lib/python3.6/site-packages/patsy/build.py in _make_subterm_infos(terms, num_column_counts, cat_levels_contrasts)
#     626                         coded = code_contrast_matrix(factor_coding[factor],
#     627                                                      levels, contrast,
# --> 628                                                      default=Treatment)
#     629                         contrast_matrices[factor] = coded
#     630                         subterm_columns *= coded.matrix.shape[1]
#
# ~/venv/lib/python3.6/site-packages/patsy/contrasts.py in code_contrast_matrix(intercept, levels, contrast, default)
#     598                               _name_levels("custom", range(as_array.shape[1])))
#     599     if intercept:
# --> 600         return contrast.code_with_intercept(levels)
#     601     else:
#     602         return contrast.code_without_intercept(levels)
#
# ~/venv/lib/python3.6/site-packages/patsy/contrasts.py in code_with_intercept(self, levels)
#     174
#     175     def code_with_intercept(self, levels):
# --> 176         return _dummy_code(levels)
#     177
#     178     def code_without_intercept(self, levels):
#
# ~/venv/lib/python3.6/site-packages/patsy/contrasts.py in _dummy_code(levels)
#     109
#     110 def _dummy_code(levels):
# --> 111     return ContrastMatrix(np.eye(len(levels)), _name_levels("", levels))
#     112
#     113 def _get_level(levels, level_ref):
#
# ~/venv/lib/python3.6/site-packages/numpy/lib/twodim_base.py in eye(N, M, k, dtype, order)
#     199     if M is None:
#     200         M = N
# --> 201     m = zeros((N, M), dtype=dtype, order=order)
#     202     if k >= M:
#     203         return m
#
# MemoryError: Unable to allocate array with shape (69158, 69158) and data type float64
